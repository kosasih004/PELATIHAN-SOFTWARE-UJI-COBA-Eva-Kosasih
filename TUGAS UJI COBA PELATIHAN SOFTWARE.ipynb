# %%
import pandas as pd

data = pd.read_csv('asuransi_mobil.csv')
print(data)
# Out:
#       Unnamed: 0  IDENTITAS                  UMUR JENIS_KELAMIN  \
# 0              0     569520   lebih dari 65 tahun     perempuan
# 1              1     750365  kurang dari 25 tahun     laki-laki
# 2              2     199901  kurang dari 25 tahun     perempuan
# 3              3     478866  kurang dari 25 tahun     laki-laki
# 4              4     731664    antara 25-40 tahun     laki-laki
# ...          ...        ...                   ...           ...
# 9995        9995     323164    antara 25-40 tahun     perempuan
# 9996        9996     910346    antara 25-40 tahun     perempuan
# 9997        9997     468409    antara 25-40 tahun     laki-laki
# 9998        9998     903459    antara 25-40 tahun     perempuan
# 9999        9999     442696    antara 25-40 tahun     perempuan
#
#       PENGALAMAN_MENGEMUDI   PENDIDIKAN        PENGHASILAN  SKOR_KREDIT  \
# 0     kurang dari 10 tahun          SMA  lebih dari 3x UMR     0.629027
# ...

# %%
data.head(100)
# Out:
#     Unnamed: 0  IDENTITAS                  UMUR JENIS_KELAMIN  \
# 0            0     569520   lebih dari 65 tahun     perempuan
# 1            1     750365  kurang dari 25 tahun     laki-laki
# 2            2     199901  kurang dari 25 tahun     perempuan
# 3            3     478866  kurang dari 25 tahun     laki-laki
# 4            4     731664    antara 25-40 tahun     laki-laki
# ..         ...        ...                   ...           ...
# 95          95     883018    antara 40-65 tahun     laki-laki
# 96          96     889355    antara 25-40 tahun     perempuan
# 97          97     198273   lebih dari 65 tahun     laki-laki
# 98          98     197763    antara 40-65 tahun     laki-laki
# 99          99      55670    antara 25-40 tahun     laki-laki
#
#     PENGALAMAN_MENGEMUDI   PENDIDIKAN        PENGHASILAN  SKOR_KREDIT  \
# 0   kurang dari 10 tahun          SMA  lebih dari 3x UMR     0.629027
# 1   kurang dari 10 tahun    tidak ada    kurang dari UMR     0.357757
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0      IDENTITAS  SKOR_KREDIT      KODE_POS  KM_PER_TAHUN  \
# count  10000.00000   10000.000000  9018.000000  10000.000000   9043.000000
# mean    4999.50000  500521.906800     0.515813  19864.548400  11697.003207
# std     2886.89568  290030.768758     0.137688  18915.613855   2818.434528
# min        0.00000     101.000000     0.053358  10238.000000   2000.000000
# 25%     2499.75000  249638.500000     0.417191  10238.000000  10000.000000
# 50%     4999.50000  501777.000000     0.525033  10238.000000  12000.000000
# 75%     7499.25000  753974.500000     0.618312  32765.000000  14000.000000
# max     9999.00000  999976.000000     0.960819  92101.000000  22000.000000
#
#        TILANG_NGEBUT  TILANG_MABUK  KECELAKAAN_SEBELUMNYA
# count   10000.000000   10000.00000           10000.000000
# mean        1.482900       0.23920               1.056300
# std         2.241966       0.55499               1.652454
# min         0.000000       0.00000               0.000000
# ...

# %%
# Melihat type data apakah berupa integer, bilangan desimal, atau data kategori
data.dtypes
# Out:
# Unnamed: 0                 int64
# IDENTITAS                  int64
# UMUR                      object
# JENIS_KELAMIN             object
# PENGALAMAN_MENGEMUDI      object
# PENDIDIKAN                object
# PENGHASILAN               object
# SKOR_KREDIT              float64
# PEMILIK_KENDARAAN         object
# TAHUN_PRODUKSI            object
# STATUS                    object
# ANAK                      object
# KODE_POS                   int64
# KM_PER_TAHUN             float64
# JENIS_KENDARAAN           object
# TILANG_NGEBUT              int64
# TILANG_MABUK               int64
# KECELAKAAN_SEBELUMNYA      int64
# KLAIM                     object
# dtype: object

# %%
# mengecek apakah terdapat data yang kosong
data.isnull().sum()
# Out:
# Unnamed: 0                 0
# IDENTITAS                  0
# UMUR                       0
# JENIS_KELAMIN              0
# PENGALAMAN_MENGEMUDI       0
# PENDIDIKAN                 0
# PENGHASILAN                0
# SKOR_KREDIT              982
# PEMILIK_KENDARAAN          0
# TAHUN_PRODUKSI             0
# STATUS                     0
# ANAK                       0
# KODE_POS                   0
# KM_PER_TAHUN             957
# JENIS_KENDARAAN            0
# TILANG_NGEBUT              0
# TILANG_MABUK               0
# KECELAKAAN_SEBELUMNYA      0
# KLAIM                      0
# dtype: int64

# %%
data_categorical =['SKOR_KREDIT','KM_PER_TAHUN']

# %%
data_drop = data.drop(data_categorical,axis=1)

# %%
data_drop.head()
# Out:
#    Unnamed: 0  IDENTITAS                  UMUR JENIS_KELAMIN  \
# 0           0     569520   lebih dari 65 tahun     perempuan
# 1           1     750365  kurang dari 25 tahun     laki-laki
# 2           2     199901  kurang dari 25 tahun     perempuan
# 3           3     478866  kurang dari 25 tahun     laki-laki
# 4           4     731664    antara 25-40 tahun     laki-laki
#
#    PENGALAMAN_MENGEMUDI   PENDIDIKAN        PENGHASILAN PEMILIK_KENDARAAN  \
# 0  kurang dari 10 tahun          SMA  lebih dari 3x UMR                ya
# 1  kurang dari 10 tahun    tidak ada    kurang dari UMR             tidak
# 2  kurang dari 10 tahun          SMA    antara 1-2x UMR                ya
# 3  kurang dari 10 tahun  universitas    antara 1-2x UMR                ya
# 4    antara 10-20 tahun    tidak ada    antara 1-2x UMR                ya
#
#   TAHUN_PRODUKSI         STATUS       ANAK  KODE_POS JENIS_KENDARAAN  \
# 0   setelah 2020  belum menikah        ada     10238        keluarga
# ...

# %%
data_drop.dtypes
# Out:
# Unnamed: 0                int64
# IDENTITAS                 int64
# UMUR                     object
# JENIS_KELAMIN            object
# PENGALAMAN_MENGEMUDI     object
# PENDIDIKAN               object
# PENGHASILAN              object
# PEMILIK_KENDARAAN        object
# TAHUN_PRODUKSI           object
# STATUS                   object
# ANAK                     object
# KODE_POS                  int64
# JENIS_KENDARAAN          object
# TILANG_NGEBUT             int64
# TILANG_MABUK              int64
# KECELAKAAN_SEBELUMNYA     int64
# KLAIM                    object
# dtype: object

# %%
data_drop.isnull().sum()
# Out:
# Unnamed: 0               0
# IDENTITAS                0
# UMUR                     0
# JENIS_KELAMIN            0
# PENGALAMAN_MENGEMUDI     0
# PENDIDIKAN               0
# PENGHASILAN              0
# PEMILIK_KENDARAAN        0
# TAHUN_PRODUKSI           0
# STATUS                   0
# ANAK                     0
# KODE_POS                 0
# JENIS_KENDARAAN          0
# TILANG_NGEBUT            0
# TILANG_MABUK             0
# KECELAKAAN_SEBELUMNYA    0
# KLAIM                    0
# dtype: int64

# %%
# Melihat apa saja isi dari kolom SKOR_KREDIT (data kategori yang tidak dapat dibandingkan)
data.SKOR_KREDIT.unique()
# Out:
# array([0.62902731, 0.35775712, 0.49314579, ..., 0.47094023, 0.36418478,
#        0.43522478])

# %%
# KM_PER_TAHUN juga merupakan data ketegori yang tidak dapat dibandingkan
data.KM_PER_TAHUN.unique()
# Out:
# array([12000., 16000., 11000., 13000., 14000., 10000.,  8000.,    nan,
#        18000., 17000.,  7000., 15000.,  9000.,  5000.,  6000., 19000.,
#         4000.,  3000.,  2000., 20000., 21000., 22000.])

# %%
# Data UMUR masih bisa dilakukan perbandingan
data.UMUR.unique()
# Out:
# array(['lebih dari 65 tahun', 'kurang dari 25 tahun',
#        'antara 25-40 tahun', 'antara 40-65 tahun'], dtype=object)

# %%
# Data PENDIDIKAN masih bisa dilakukan perbandingan
data.PENDIDIKAN.unique()
# Out:
# array(['SMA', 'tidak ada', 'universitas'], dtype=object)

# %%
# Melakukan mapping dari Pendidikan karena walaupun pendidikan merupakan data kategori, akan tetapi
# terdapat peningkatan dari SMA, tidak ada dan Universitas.
data['PENDIDIKAN'] = \
data['PENDIDIKAN'].map({'universitas':2,'SMA':1,'tidak ada':0})

# %%
# Untuk melihat apa aja isi dari kolom PENGHASILAN (merupakan data yang dapat dibandingkan)
data.PENGHASILAN.unique()
# Out:
# array(['lebih dari 3x UMR', 'kurang dari UMR', 'antara 1-2x UMR',
#        'antara 2-3x UMR'], dtype=object)

# %%
data['PEMILIK_KENDARAAN'] = \
data['PEMILIK_KENDARAAN'].map({'tidak':0,'ya':1})

# %%
data.TAHUN_PRODUKSI.unique()
# Out:
# array(['setelah 2020', 'sebelum 2020'], dtype=object)

# %%
data['TAHUN_PRODUKSI'] = \
data['TAHUN_PRODUKSI'].map({'sebelum 2020':0,'setelah 2020':1})

# %%
data.STATUS.unique()
# Out:
# array(['belum menikah', 'menikah'], dtype=object)

# %%
data['STATUS'] = \
data['STATUS'].map({'belum menikah':0,'menikah':1})

# %%
data.ANAK.unique()
# Out:
# array(['ada', 'tidak ada'], dtype=object)

# %%
data['ANAK'] = \
data['ANAK'].map({'tidak ada':0,'ada':1})

# %%
data.JENIS_KENDARAAN.unique()
# Out:
# array(['keluarga', 'sport'], dtype=object)

# %%
data['JENIS_KENDARAAN'] = \
data['JENIS_KENDARAAN'].map({'keluarga':0,'sport':1})

# %%
data.KLAIM.unique()
# Out:
# array(['tidak', 'ya'], dtype=object)

# %%
data['KLAIM'] = \
data['KLAIM'].map({'tidak':0,'ya':1})

# %%
data.describe()
# Out:
#         Unnamed: 0      IDENTITAS  PENDIDIKAN  SKOR_KREDIT  PEMILIK_KENDARAAN  \
# count  10000.00000   10000.000000         0.0  9018.000000       10000.000000
# mean    4999.50000  500521.906800         NaN     0.515813           0.697000
# std     2886.89568  290030.768758         NaN     0.137688           0.459578
# min        0.00000     101.000000         NaN     0.053358           0.000000
# 25%     2499.75000  249638.500000         NaN     0.417191           0.000000
# 50%     4999.50000  501777.000000         NaN     0.525033           1.000000
# 75%     7499.25000  753974.500000         NaN     0.618312           1.000000
# max     9999.00000  999976.000000         NaN     0.960819           1.000000
#
#        TAHUN_PRODUKSI        STATUS          ANAK      KODE_POS  KM_PER_TAHUN  \
# count    10000.000000  10000.000000  10000.000000  10000.000000   9043.000000
# mean         0.303300      0.498200      0.688800  19864.548400  11697.003207
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'IDENTITAS', 'UMUR', 'JENIS_KELAMIN',
#        'PENGALAMAN_MENGEMUDI', 'PENDIDIKAN', 'PENGHASILAN', 'SKOR_KREDIT',
#        'PEMILIK_KENDARAAN', 'TAHUN_PRODUKSI', 'STATUS', 'ANAK', 'KODE_POS',
#        'KM_PER_TAHUN', 'JENIS_KENDARAAN', 'TILANG_NGEBUT', 'TILANG_MABUK',
#        'KECELAKAAN_SEBELUMNYA', 'KLAIM'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Unnamed: 0                 int64
# IDENTITAS                  int64
# UMUR                      object
# JENIS_KELAMIN             object
# PENGALAMAN_MENGEMUDI      object
# PENDIDIKAN               float64
# PENGHASILAN               object
# SKOR_KREDIT              float64
# PEMILIK_KENDARAAN          int64
# TAHUN_PRODUKSI             int64
# STATUS                     int64
# ANAK                       int64
# KODE_POS                   int64
# KM_PER_TAHUN             float64
# JENIS_KENDARAAN            int64
# TILANG_NGEBUT              int64
# TILANG_MABUK               int64
# KECELAKAAN_SEBELUMNYA      int64
# KLAIM                      int64
# dtype: object

# %%
data_categorical =['KM_PER_TAHUN','SKOR_KREDIT']
data_numeric =['UMUR','PENDIDIKAN','PENGALAMAN_MENGEMUDI ','KECELAKAAN_SEBELUMNYA','PENGHASILAN']
data_binary = ['JENIS_KENDARAAN','ANAK','TAHUN_PRODUKSI','STATUS','JENIS_KELAMIN']
data_target = ['KLAIM']
